# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

MMMData = pd.read_csv("3m_stock_prices.csv")
uselessData = ["High","Low","Adj Close"]
keyMMMData = MMMData.drop(columns=UselessData)

# %%
dates = keyMMMData["Date"]
closeValues = keyMMMData["Close"]
openValues = keyMMMData["Open"]

plt.plot_date(dates,closeValues)
